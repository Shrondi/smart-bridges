# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrondi/smart-bridges/blob/main/fix_data_smartbridges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción

# %% [markdown]
# Los **acelerómetros** instalados en los puentes presentan un problema al volcar los datos en la base de datos: los ejes aparecen intercambiados.
#
# Inicialmente, se intentó esquivar este error mediante una consulta `SELECT` en SQL que solucionaba el problema cada vez que se hacía una consulta. Sin embargo, debido a su lentitud y complejidad, se decidió implementar una solución más eficiente y definitiva: desarrollar un **algoritmo** capaz de detectar automáticamente los **intercambios** de ejes y corregir los datos directamente en la base de datos.
#
# Lo que en un principio parecía un simple error de intercambio de ejes en algunos bloques de datos resultó ser más complejo, ya que se identificaron múltiples tipos de errores en las muestras.

# %% [markdown]
# # Planteamiento del problema

# %% [markdown]
# ## Análisis inicial

# %% [markdown]
# Cada puente está conformado por 8 sensores colocados de forma simétrica y repartidos equitativamente a cada lado de las vías.
#
# Cada uno de los acelerómetros esta configurado con unos determinados parámetros: frecuencia, escala y tamaño de la palabra.
#
# Cada una de las muestras de los acelerómetros contiene una medición en crudo de los ejes z, x e y. Un conjunto de muestras a una determinada frecuencia forma un datablock.

# %% [markdown]
# Como se observó a posteriori, los acelerómetros intercambiaban en las muestras los datos de los ejes z, x e y de forma aleatoria y sin ningún patrón aparente.
#
# Por tanto, era necesario arreglar las muestras y datablocks que presentaban algún tipo de problema por cada uno de los acelerómetros.

# %% [markdown]
# ## Errores y filtrado

# %% [markdown]
# El análisis de los datos de los acelerómetros reveló que los errores no se limitaban únicamente al intercambio de ejes en algunos bloques de datos, sino que eran más variados:
#
# * **Outliers**: dentro de un bloque de datos, se encontraba una única muestra con un valor absurdo en alguno de sus ejes.
#
# * **Muestras erróneas**: algunos bloques de datos contenían valores incorrectos en sus últimas muestras, generalmente 0.0, 0.25 o 1.0. En comparación con las muestras correctas, estos valores eran claramente anormales.
#
# * **Intercambio completo de ejes**: En ciertos bloques, los ejes estaban completamente intercambiados, por ejemplo, (Z, X, Y) o (X, Y, Z).
#
# * **Intercambio parcial de ejes**: La mayoría de los bloques presentaban sus últimas muestras con los ejes intercambiados, generalmente después de haber registrado errores del tipo anterior.

# %% [markdown]
# Previamente, para determinar qué datablocks eran erróneos y cuáles eran correctos, era necesario definir un criterio de filtrado:
#
# Se calcula la media aritmética de cada eje por datablock, y aquellos datablocks cuyos valores estuvieran fuera del intervalo:
#
# $
# \mu \pm (\tau \cdot \sigma)
# $
#
# se consideraban erróneos.
#
# Donde:
# - $\mu$ representa la media del datablock.
# - $\tau$ representa un umbral (threshold).
# - $\sigma$ representa la desviación estándar del datablock

# %% [markdown]
# ## Intercambio de ejes

# %% [markdown]
# La solución del intercambio de ejes esta formado por dos etapas:
# 1. Analizar los datablocks para buscar aquellas muestras con ejes intercambiados.
# 2. Analizar los datablocks de forma completa e intercambiar sus ejes.

# %% [markdown]
# Para el primer caso, se recorre cada uno de los datablocks y se comparaban los ejes de la muestra actual con la anterior para determinar si ha habido un intercambio (Y, X, Z) o (Z, X, Y)

# %% [markdown]
# ```
# Algoritmo fix_samples_datablocks
#     Filtrar datos eliminando filas con menos de 3 decimales en x, y o z
#
#     Para cada grupo de datos agrupados por 'data_block' hacer
#         Para cada fila en el grupo desde la segunda hasta la última hacer
#             prev_row = Fila anterior
#             row = Fila actual
#
#             // Verificar si los ejes están intercambiados
#             Si ejes (Z, X, Y) entonces
#                 Intercambiar x = z en la fila actual
#                 Intercambiar x = y en la fila actual
#
#                 Ejecutar consulta UPDATE SQL
#
#             Sino ejes (Y, Z, X) entonces
#                 Intercambiar y = z en la fila actual
#                 Intercambiar x = y en la fila actual
#
#                 Ejecutar consulta UPDATE SQL
#
#             Fin Si
#           Fin Para
#       Fin Para
#
# Fin Algoritmo
# ```

# %% [markdown]
# Para el segundo caso, se calcula la media de cada uno de los ejes de cada datablock, y se recorren los datablock comparando las medias de cada uno de los ejes del datablock actual con las medias de los ejes del datablock anterior para determinar si ha habido intercambio en los ejes.

# %% [markdown]
# ```
# Algoritmo fix_datablocks
#
#     // Obtener valores únicos de data_block
#     data_blocks = obtener_data_blocks_unicos(df_raw)
#
#     // Iterar sobre cada data_block
#     Para cada data_block en data_blocks:
#
#         // Obtener el data_block actual y el bloque anterior
#         current_data_block = data_block
#         prev_data_block = obtener_bloque_anterior()
#
#         // Obtener las medias de los ejes para el bloque actual y el bloque anterior (si existe)
#         current_means = obtener_medias_ejes()
#         prev_block_means = obtener_medias_ejes() si prev_data_block existe
#
#         Si prev_block_means existe:
#
#             Si ejes (Z, X, Y):
#
#                 Ejecutar consulta UPDATE SQL
#
#             Sino si ejes (Y, Z, X):
#
#                 Ejecutar consulta UPDATE SQL
#
#             Fin Si
#
#         Fin Si
#
#       Fin Para
#
# Fin Algoritmo
# ```

# %% [markdown]
# Cabe destacar, que previamente hay que limpiar las muestras erróneas de los datablock para que así las medias no salgan alteradas y no haya errores a la hora de intercambiar.

# %% [markdown]
# ## Solución

# %% [markdown]
# En resumen, los pasos de la solución adoptada son:
#   1. Elegir un acelerómetro y un rango temporal. Preferiblemente no más de un día para evitar problemas de bloqueos o memoria.
#   2. Filtrar los datablocks correctos de los erróneos.
#   3. Obtener la media de cada eje para todos los datablocks erróneos.
#   4. Eliminar las muestras erróneas de los databloks.
#   5. Iterar sobre cada datablock para corregir el intercambio de los ejes en las muestras.
#   6. Recorrer los datablocks para corregir sus ejes.

# %% [markdown]
# # Código

# %% [markdown]
# ## Importación e instalación

# %%
# Acelerómetros:
# ADXL355, 20bits, +-2g, 125Hz:  https://www.analog.com/media/en/technical-documentation/data-sheets/adxl354_adxl355.pdf

# !pip install -q mysql-connector-python mysqlclient
# !pip install -q pandas
# !pip install -q matplotlib
# !pip install -q plotly
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 8.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 58.8 MB/s eta 0:00:00
#   Building wheel for mysqlclient (pyproject.toml) ... done

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Definición funciones

# %% [markdown]
# ### Funciones BD

# %%
def get_stats_datablocks(accelerometer, datetime_init, datetime_end):

  """ Obtención de la media aritmética de los ejes de cada bloque de datos """

  querystr = f"""\
    SELECT
          da.data_block,
          AVG(axisx) AS avg_x,
          AVG(axisy) AS avg_y,
          AVG(axisz) AS avg_z
      FROM data_accelerometer da
      JOIN data_block db ON da.data_block = db.id
      JOIN configuration_acc ca ON ca.id = db.configuration
      JOIN accelerometer ac ON ac.sensor = ca.accelerometer
      JOIN chip ch ON ch.id = ac.chip
      WHERE time_begin BETWEEN '{datetime_init}' AND '{datetime_end}'
        AND ac.sensor = {accelerometer}
      GROUP BY da.data_block
      """

  cursor.execute(querystr)

  return cursor.fetchall()

# %%
def get_datablocks_data(datablocks):

    """ Obtención de los datos de los bloques de datos """
    querystr = f"""
      SELECT
          DATE_ADD(
              time_begin,
              INTERVAL
              (
                  CASE
                      WHEN ca.frequency = 0 THEN 1/31.25
                      ELSE 1/125
                  END
              ) * (
                  SELECT COUNT(*)
                  FROM data_accelerometer da_inner
                  WHERE da_inner.data_block = da.data_block
                  AND da_inner.id <= da.id
              ) - 1
              SECOND_MICROSECOND
          ) AS incrementada,

          axisx * (POW(2, scale+2) / POW(2, word_bits)) AS x,
          axisy * (POW(2, scale+2) / POW(2, word_bits)) AS y,
          axisz * (POW(2, scale+2) / POW(2, word_bits)) AS z,
          da.data_block,
          da.id
      FROM
          data_block db
          JOIN data_accelerometer da ON da.data_block = db.id
          JOIN configuration_acc ca ON ca.id = db.configuration
          JOIN accelerometer ac ON ac.sensor = ca.accelerometer
          JOIN chip ch ON ch.id = ac.chip
      WHERE
      da.data_block IN ({datablocks})
      """

    cursor.execute(querystr)

    return cursor.fetchall()

# %%
def get_acelerometer_data(accelerometer, datetime_init, datetime_end):

  """ Obtención de los datos de los acelerómetros """

    querystr = f"""\
    SELECT
        DATE_ADD(
        time_begin,
        INTERVAL
        (
            CASE
                WHEN ca.frequency = 0 THEN 1/31.25
                ELSE 1/125
            END
        ) * (
            SELECT COUNT(*)
            FROM data_accelerometer da_inner
            WHERE da_inner.data_block = da.data_block
            AND da_inner.id <= da.id
        ) - 1
        SECOND_MICROSECOND
    ) AS incrementada,

    axisx * (POW(2, scale+2) / POW(2, word_bits)) AS x,
	  axisy * (POW(2, scale+2) / POW(2, word_bits)) AS y,
	  axisz * (POW(2, scale+2) / POW(2, word_bits)) AS z

    FROM
        data_block db
        JOIN data_accelerometer da ON da.data_block = db.id
        JOIN configuration_acc ca ON ca.id = db.configuration
        JOIN accelerometer ac ON ac.sensor = ca.accelerometer
        JOIN chip ch ON ch.id = ac.chip
    WHERE
        time_begin BETWEEN '{datetime_init}' AND '{datetime_end}'
        AND ac.sensor = {accelerometer}"""

    cursor.execute(querystr)

    return cursor.fetchall()

# %% [markdown]
# ### Funciones procesamiento datos

# %%
def plot_acelerometer_data(data, axes=['z', 'y', 'x'], min_date=None, max_date=None):

  df = pd.DataFrame(data, columns=['datetime', 'x', 'y', 'z', 'data_block', 'id'])
  df.set_index('datetime', inplace=True)
  df.sort_values('datetime', inplace=True)

  df = df[['x', 'y', 'z', 'data_block']]

  fig, ax = plt.subplots(figsize=(10, 3))

  # Configurar la escala temporal si se proporcionan min_date y max_date
  if min_date is not None and max_date is not None:
    min_date = pd.to_datetime(min_date)
    max_date = pd.to_datetime(max_date)
    ax.set_xlim(min_date, max_date)

    df = df[(df.index >= min_date) & (df.index <= max_date)]

  # Graficar la aceleración en cada eje
  colors = {'x': 'b', 'y': 'y', 'z': 'g'}
  for axis in axes:
    if axis in df.columns:
      ax.plot(df.index, df[axis], label=axis.upper(), color=colors.get(axis))

  # Configurar el título y las etiquetas de los ejes
  ax.set_title('Accel. data', fontsize=12,fontweight='bold')
  ax.set_xlabel('tiempo', fontsize=12)
  ax.set_ylabel('aceleración [g]', fontsize=12)

  ax.tick_params(axis='x', labelsize=12)

  ax.legend(loc="lower left")

  # Configurar el borde sólido de la zona de representación de datos
  ax.spines['left'].set_linewidth(1)
  ax.spines['bottom'].set_linewidth(1)
  ax.spines['right'].set_linewidth(1)
  ax.spines['top'].set_linewidth(1)

  # Configurar la rejilla de líneas punteadas y semitransparentes
  ax.grid(which='major', linestyle='--', alpha=0.5)
  ax.grid(which='minor', linestyle=':', alpha=0.3)

  plt.show()

  return df

# %%
def filter_datablocks(data, threshold):
    """ Filtrar los datablocks que estén fuera de media ± (threshold * desviación estándar) """

    df = pd.DataFrame(data, columns=['data_block', 'avg_x', 'avg_y', 'avg_z'])
    df.set_index('data_block', inplace=True)

    df = df.astype(float)

    # Guardar todos los data_blocks iniciales
    all_datablocks = df.index.tolist()

    for col in ['avg_x', 'avg_y', 'avg_z']:
      mean = df[col].mean()
      std = df[col].std()
      df = df[(df[col] >= mean - threshold * std) & (df[col] <= mean + threshold * std)]

    # Convertir el índice a una cadena
    good_datablocks_str = ', '.join(map(str, df.index.tolist()))

    # Obtener los data_blocks eliminados
    removed_datablocks = list(set(all_datablocks) - set(df.index.tolist()))
    removed_datablocks_str = ', '.join(map(str, removed_datablocks))

    return good_datablocks_str, removed_datablocks_str

# %%
def fix_samples_datablocks(bad_data, THRESHOLD_FIX_SAMPLES, ACELEROMETRO, FECHA_HORA_INICIO, FECHA_HORA_FIN):
    """
    Analiza las muestras de los datablocks intercambiando los ejes de las muestras que lo requieran.
    Además, elimina aquellas muestras que tengan una precisión decimal menor a 3 decimales (muestras erróneas)

    Return:
        DataFrame con los datos arreglados
    """

    # Convertir bad_data a Pandas DataFrame
    df = pd.DataFrame(bad_data, columns=['datetime', 'x', 'y', 'z', 'data_block', 'id'])

    # Eliminar filas con baja precisión decimal (menos de 3 decimales)
    df = df[df['x'].apply(lambda x: len(str(x).split('.')[1]) >= 3) & \
            df['y'].apply(lambda x: len(str(x).split('.')[1]) >= 3) & \
            df['z'].apply(lambda x: len(str(x).split('.')[1]) >= 3)]


    def correct_axes(group):
      """ Función para corregir los ejes de las muestras que lo requieran de un datablock """

        for i in range(1, len(group)):
            prev_row = group.iloc[i - 1]
            row = group.iloc[i]

            # Condición de ejes intercambiados
            ejes_intercambiadosA = (
                (np.abs(float(row['x'])) >= np.abs(float(prev_row['z'])) - THRESHOLD_FIX_SAMPLES) and (np.abs(float(row['x'])) <= np.abs(float(prev_row['z'])) + THRESHOLD_FIX_SAMPLES) and
                (np.abs(float(row['y'])) >= np.abs(float(prev_row['x'])) - THRESHOLD_FIX_SAMPLES) and (np.abs(float(row['y'])) <= np.abs(float(prev_row['x'])) + THRESHOLD_FIX_SAMPLES) and
                (np.abs(float(row['z'])) >= np.abs(float(prev_row['y'])) - THRESHOLD_FIX_SAMPLES) and (np.abs(float(row['z'])) <= np.abs(float(prev_row['y'])) + THRESHOLD_FIX_SAMPLES)
            )

            ejes_intercambiadosB = (
                (np.abs(float(row['x'])) >= np.abs(float(prev_row['y'])) - THRESHOLD_FIX_SAMPLES) and (np.abs(float(row['x'])) <= np.abs(float(prev_row['y'])) + THRESHOLD_FIX_SAMPLES) and
                (np.abs(float(row['y'])) >= np.abs(float(prev_row['z'])) - THRESHOLD_FIX_SAMPLES) and (np.abs(float(row['y'])) <= np.abs(float(prev_row['z'])) + THRESHOLD_FIX_SAMPLES) and
                (np.abs(float(row['z'])) >= np.abs(float(prev_row['x'])) - THRESHOLD_FIX_SAMPLES) and (np.abs(float(row['z'])) <= np.abs(float(prev_row['x'])) + THRESHOLD_FIX_SAMPLES)
            )


            row_id = row['id']

            # Intercambiar ejes solo para la muestra actual si se detecta un intercambio de ejes
            if ejes_intercambiadosA:

                # Intercambiar X y Z
                group.loc[group.index[i], ['x', 'z']] = group.loc[group.index[i], ['z', 'x']].values
                # Intercambiar X e Y
                group.loc[group.index[i], ['x', 'y']] = group.loc[group.index[i], ['y', 'x']].values

                update_query = f"""
                UPDATE data_accelerometer
                SET axisx = {row['y']}, axisy = {row['z']}, axisz = {row['x']}
                WHERE id = {row_id}
                """
                cursor.execute(update_query)
                db.commit()

                print(update_query)

            elif ejes_intercambiadosB:

                # Intercambiar Y y Z
                group.loc[group.index[i], ['y', 'z']] = group.loc[group.index[i], ['z', 'y']].values
                # Intercambiar Y e X
                group.loc[group.index[i], ['x', 'y']] = group.loc[group.index[i], ['y', 'x']].values

                update_query = f"""
                UPDATE data_accelerometer
                SET axisx = {row['z']}, axisy = {row['x']}, axisz = {row['y']}
                WHERE id = {row_id}
                """

                cursor.execute(update_query)
                db.commit()

                print(update_query)

        return group

    # Aplicar la función por cada datablock
    df = df.groupby('data_block').apply(correct_axes).reset_index(drop=True)

    # 2. Construir la consulta SQL para eliminar datos con baja precisión decimal
    delete_query = f"""
    DELETE da FROM data_accelerometer da
    JOIN data_block db ON da.data_block = db.id
    JOIN configuration_acc ca ON ca.id = db.configuration
    JOIN accelerometer ac ON ac.sensor = ca.accelerometer
    JOIN chip ch ON ch.id = ac.chip
    WHERE (LENGTH(SUBSTR(axisx * (POW(2, scale+2) / POW(2, word_bits)), INSTR(axisx * (POW(2, scale+2) / POW(2, word_bits)), '.') + 1)) < 3
          OR LENGTH(SUBSTR(axisy * (POW(2, scale+2) / POW(2, word_bits)), INSTR(axisy * (POW(2, scale+2) / POW(2, word_bits)), '.') + 1)) < 3
          OR LENGTH(SUBSTR(axisz * (POW(2, scale+2) / POW(2, word_bits)), INSTR(axisz * (POW(2, scale+2) / POW(2, word_bits)), '.') + 1)) < 3)
      AND ac.sensor = {ACELEROMETRO}
      AND db.time_begin BETWEEN '{FECHA_HORA_INICIO}' AND '{FECHA_HORA_FIN}';
    """

    cursor.execute(delete_query)
    db.commit()

    return df

# %%
def fix_datablocks(datablock_raw, THRESHOLD_FIX_DATABLOCKS):
    """
    Arregla los datablocks intercambiando sus ejes usando la media por cada eje para
    comparar con la media del bloque anterior.

    Returns:
        Un DataFrame que representan los datos de los datablocks arreglados.
    """

    # Convertir datablock_raw a Pandas DataFrame
    df_raw = pd.DataFrame(datablock_raw, columns=['data_block', 'avg_x', 'avg_y', 'avg_z'])
    df_raw.set_index('data_block', inplace=True)

    df_raw = df_raw.astype(float)

    # Get unique data_block values
    data_blocks = df_raw.index.unique()

    # Iterate over data_blocks
    for i in range(len(data_blocks)):
        current_data_block = data_blocks[i]
        prev_data_block = data_blocks[i - 1] if i > 0 else None  # Get previous block if available

        # Get current and previous block means
        current_means = df_raw.loc[current_data_block, ['avg_x', 'avg_y', 'avg_z']]
        prev_block_means = df_raw.loc[prev_data_block, ['avg_x', 'avg_y', 'avg_z']] if prev_data_block is not None and prev_data_block in df_raw.index else None

        # Compara las medias con las del bloque anterior (si está disponible)
        if prev_block_means is not None:
            # Condición de ejes intercambiados (utilizando la media)
            ejes_intercambiadosA = (
                (np.abs(float(current_means['avg_x'])) >= np.abs(float(prev_block_means['avg_z'])) - THRESHOLD_FIX_DATABLOCKS) and (np.abs(float(current_means['avg_x'])) <= np.abs(float(prev_block_means['avg_z'])) + THRESHOLD_FIX_DATABLOCKS) and
                (np.abs(float(current_means['avg_y'])) >= np.abs(float(prev_block_means['avg_x'])) - THRESHOLD_FIX_DATABLOCKS) and (np.abs(float(current_means['avg_y'])) <= np.abs(float(prev_block_means['avg_x'])) + THRESHOLD_FIX_DATABLOCKS) and
                (np.abs(float(current_means['avg_z'])) >= np.abs(float(prev_block_means['avg_y'])) - THRESHOLD_FIX_DATABLOCKS) and (np.abs(float(current_means['avg_z'])) <= np.abs(float(prev_block_means['avg_y'])) + THRESHOLD_FIX_DATABLOCKS)
            )

            ejes_intercambiadosB = (
                (np.abs(float(current_means['avg_x'])) >= np.abs(float(prev_block_means['avg_y'])) - THRESHOLD_FIX_DATABLOCKS) and (np.abs(float(current_means['avg_x'])) <= np.abs(float(prev_block_means['avg_y'])) + THRESHOLD_FIX_DATABLOCKS) and
                (np.abs(float(current_means['avg_y'])) >= np.abs(float(prev_block_means['avg_z'])) - THRESHOLD_FIX_DATABLOCKS) and (np.abs(float(current_means['avg_y'])) <= np.abs(float(prev_block_means['avg_z'])) + THRESHOLD_FIX_DATABLOCKS) and
                (np.abs(float(current_means['avg_z'])) >= np.abs(float(prev_block_means['avg_x'])) - THRESHOLD_FIX_DATABLOCKS) and (np.abs(float(current_means['avg_z'])) <= np.abs(float(prev_block_means['avg_x'])) + THRESHOLD_FIX_DATABLOCKS)
            )

            # Intercambiar los valores medios si se detecta un intercambio
            if ejes_intercambiadosA:
                # Intercambiar X y Z
                df_raw.loc[current_data_block, ['avg_x', 'avg_z']] = df_raw.loc[current_data_block, ['avg_z', 'avg_x']].values
                # Intercambiar X e Y (ahora Y es el original X)
                df_raw.loc[current_data_block, ['avg_x', 'avg_y']] = df_raw.loc[current_data_block, ['avg_y', 'avg_x']].values

                update_query = f"""
                UPDATE data_accelerometer AS d
                JOIN (
                    SELECT id, axisx AS old_axisx, axisy AS old_axisy, axisz AS old_axisz
                    FROM data_accelerometer
                    WHERE data_block = {current_data_block}
                ) AS temp
                ON d.id = temp.id
                SET d.axisx = temp.old_axisy,
                    d.axisy = temp.old_axisz,
                    d.axisz = temp.old_axisx
                WHERE d.data_block = {current_data_block};

                """

                # Ejecutar la consulta SQL
                cursor.execute(update_query)
                db.commit()  # Confirmar los cambios en la base de datos
                print(update_query)

            elif ejes_intercambiadosB:
                # Intercambiar Y y Z
                df_raw.loc[current_data_block, ['avg_y', 'avg_z']] = df_raw.loc[current_data_block, ['avg_z', 'avg_y']].values
                # Intercambiar X e Y (ahora Y es el original X)
                df_raw.loc[current_data_block, ['avg_x', 'avg_y']] = df_raw.loc[current_data_block, ['avg_y', 'avg_x']].values

                update_query = f"""
                UPDATE data_accelerometer AS d
                JOIN (
                    SELECT id, axisx AS old_axisx, axisy AS old_axisy, axisz AS old_axisz
                    FROM data_accelerometer
                    WHERE data_block = {current_data_block}
                ) AS temp
                ON d.id = temp.id
                SET d.axisx = temp.old_axisz,
                    d.axisy = temp.old_axisx,
                    d.axisz = temp.old_axisy
                WHERE d.data_block = {current_data_block};

                """

                # Ejecutar la consulta SQL
                cursor.execute(update_query)
                db.commit()  # Confirmar los cambios en la base de datos
                print(update_query)

    return df_raw  # Return the modified DataFrame

# %% [markdown]
# ## Variables

# %%
MYSQL_HOST = '79.116.81.120'
MYSQL_DATABASE = 'smart-bridges'
MYSQL_USER = 'user'
MYSQL_PASSWORD = 'e5iLFLqq54t7fc(s'

FECHA_HORA_INICIO        = '2025-03-01 00:00:00'
FECHA_HORA_FIN           = '2025-03-02 00:00:00'
ACELEROMETRO             = 4
THRESHOLD_FILTER         = 2                     # Se usa para filtrar los datablocks buenos de los erroneos en la funcion filter_datablocks: media ± (threshold * desviación estándar)
THRESHOLD_FIX_DATABLOCKS = 50                    # Diferencia entre medias de los ejes de los datablocks (Las medias estan calculadas sobre los datos raw de los sensores)
THRESHOLD_FIX_SAMPLES    = 0.2                   # Diferencia entre aceleraciones de los ejes entre distintas muestras dentro de un mismo datablock

# %% [markdown]
# ## Datos sin arregl

# %%
try:
  db = mysql.connector.connect(
    host = MYSQL_HOST,
    user = MYSQL_USER,
    password = MYSQL_PASSWORD,
    database = MYSQL_DATABASE
  )

  db.start_transaction()
  cursor = db.cursor()
  print("Conexión a la BBDD ok")

except Exception as e:
  print("Error al conectar a la BBDD: ", e)
# Out:
# Conexión a la BBDD ok

# %%
df_data_raw = get_data(ACELEROMETRO, FECHA_HORA_INICIO, FECHA_HORA_FIN) # Datos sin procesar
plot_data(df_data_raw) # Mostrar los datos antes del procesamiento
# Out:
#                                    x         y         z  data_block
# datetime
# 2025-02-28 23:59:59.142464  0.115997 -0.020130  0.984203     3299259
# 2025-02-28 23:59:59.150464  0.115795 -0.020096  0.984169     3299259
# 2025-02-28 23:59:59.158464  0.115715 -0.020149  0.984272     3299259
# 2025-02-28 23:59:59.166464  0.115906 -0.019989  0.984348     3299259
# 2025-02-28 23:59:59.174464  0.115822 -0.020119  0.984104     3299259
# ...                              ...       ...       ...         ...
# 2025-03-01 23:59:59.150136  0.116001 -0.020012  0.984180     4058658
# 2025-03-01 23:59:59.158136  0.116062 -0.020020  0.984215     4058658
# 2025-03-01 23:59:59.166136  0.115952 -0.020237  0.984219     4058658
# 2025-03-01 23:59:59.174136  0.115891 -0.020088  0.984245     4058658
# 2025-03-01 23:59:59.182136  0.115917 -0.020119  0.984318     4058658
#
# [10812587 rows x 4 columns]

# %% [markdown]
# # Procesamiento de datos

# %%
datablock_stats = get_stats_datablocks(ACELEROMETRO, FECHA_HORA_INICIO, FECHA_HORA_FIN) # Obtener la media de cada eje por datablock

str_datablocks_good, str_datablocks_bad = filter_datablocks(datablock_stats, THRESHOLD_FILTER) # Filtrar datablocks que estén fuera de media ± (threshold * desviación estándar)

good_data = get_datablocks_data(str_datablocks_good) # Obtener los datos de los datablocks sanos
bad_data = get_datablocks_data(str_datablocks_bad) # Obtener los datos de los datablocks para arreglar

df_bad_data = plot_acelerometer_data(bad_data)
df_good_data = plot_acelerometer_data(good_data)

# %%
# Se han limpiado aquellos datablocks que tenian solo algunas muestras erroneas o cambiados los ejes

fixed_samples_data = fix_samples_datablocks(bad_data, THRESHOLD_FIX_SAMPLES, ACELEROMETRO, FECHA_HORA_INICIO, FECHA_HORA_FIN)
plot_acelerometer_data(fixed_samples_data) # Datablocks mejorados
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11599349975585938, axisy = -0.0200653076171875, axisz = 0.9842147827148438
#                 WHERE id = 111607830
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590194702148438, axisy = -0.020015716552734375, axisz = 0.9839553833007812
#                 WHERE id = 111607831
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598587036132812, axisy = -0.02007293701171875, axisz = 0.9839324951171875
#                 WHERE id = 111607832
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.02022552490234375, axisz = 0.9839744567871094
#                 WHERE id = 111607833
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115936279296875, axisy = -0.02010345458984375, axisz = 0.9842071533203125
#                 WHERE id = 111607834
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.0199737548828125, axisz = 0.9843597412109375
#                 WHERE id = 111607835
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597061157226562, axisy = -0.020130157470703125, axisz = 0.9842185974121094
#                 WHERE id = 111607836
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11608505249023438, axisy = -0.02014923095703125, axisz = 0.9842796325683594
#                 WHERE id = 111607837
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603927612304688, axisy = -0.020233154296875, axisz = 0.984039306640625
#                 WHERE id = 111607838
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11609268188476562, axisy = -0.02030181884765625, axisz = 0.9840469360351562
#                 WHERE id = 111607839
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.020206451416015625, axisz = 0.9841804504394531
#                 WHERE id = 111607840
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1158599853515625, axisy = -0.020114898681640625, axisz = 0.9842529296875
#                 WHERE id = 111607841
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590194702148438, axisy = -0.0202484130859375, axisz = 0.9841537475585938
#                 WHERE id = 111607842
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020168304443359375, axisz = 0.9841804504394531
#                 WHERE id = 111607843
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115966796875, axisy = -0.02031707763671875, axisz = 0.9843063354492188
#                 WHERE id = 111607844
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159210205078125, axisy = -0.02016448974609375, axisz = 0.9843368530273438
#                 WHERE id = 111607845
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11577224731445312, axisy = -0.020168304443359375, axisz = 0.9840965270996094
#                 WHERE id = 111607846
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11593246459960938, axisy = -0.02022552490234375, axisz = 0.9841766357421875
#                 WHERE id = 111607925
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594772338867188, axisy = -0.0201568603515625, axisz = 0.9842948913574219
#                 WHERE id = 111607926
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11589431762695312, axisy = -0.020175933837890625, axisz = 0.9841651916503906
#                 WHERE id = 111607927
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592864990234375, axisy = -0.020267486572265625, axisz = 0.9842185974121094
#                 WHERE id = 111607928
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11593246459960938, axisy = -0.0202484130859375, axisz = 0.9845390319824219
#                 WHERE id = 111607929
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594772338867188, axisy = -0.02032470703125, axisz = 0.9842643737792969
#                 WHERE id = 111607930
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.020244598388671875, axisz = 0.98431396484375
#                 WHERE id = 111607931
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115814208984375, axisy = -0.0201873779296875, axisz = 0.9840927124023438
#                 WHERE id = 111607932
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.0203094482421875, axisz = 0.9840164184570312
#                 WHERE id = 111607933
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603164672851562, axisy = -0.02021026611328125, axisz = 0.9842605590820312
#                 WHERE id = 111607934
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591339111328125, axisy = -0.020172119140625, axisz = 0.9841461181640625
#                 WHERE id = 111607935
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.020191192626953125, axisz = 0.9842681884765625
#                 WHERE id = 111607936
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11589431762695312, axisy = -0.02024078369140625, axisz = 0.9842987060546875
#                 WHERE id = 111607937
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595916748046875, axisy = -0.020313262939453125, axisz = 0.9842567443847656
#                 WHERE id = 111607938
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.020259857177734375, axisz = 0.98419189453125
#                 WHERE id = 111607939
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020168304443359375, axisz = 0.9842720031738281
#                 WHERE id = 111607940
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591339111328125, axisy = -0.020198822021484375, axisz = 0.9842414855957031
#                 WHERE id = 111607941
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590576171875, axisy = -0.02024078369140625, axisz = 0.9845695495605469
#                 WHERE id = 111607942
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11614227294921875, axisy = -0.020233154296875, axisz = 0.9841651916503906
#                 WHERE id = 111607943
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160125732421875, axisy = -0.020160675048828125, axisz = 0.98394775390625
#                 WHERE id = 111607944
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602783203125, axisy = -0.0201263427734375, axisz = 0.9841423034667969
#                 WHERE id = 111607945
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116119384765625, axisy = -0.020114898681640625, axisz = 0.9841461181640625
#                 WHERE id = 111607946
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11604690551757812, axisy = -0.020275115966796875, axisz = 0.9842109680175781
#                 WHERE id = 111607947
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160736083984375, axisy = -0.02024078369140625, axisz = 0.9842376708984375
#                 WHERE id = 111607948
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591720581054688, axisy = -0.020252227783203125, axisz = 0.9842414855957031
#                 WHERE id = 111608002
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11613082885742188, axisy = -0.020168304443359375, axisz = 0.9842872619628906
#                 WHERE id = 111608003
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11586380004882812, axisy = -0.020198822021484375, axisz = 0.9842300415039062
#                 WHERE id = 111608004
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115966796875, axisy = -0.0201416015625, axisz = 0.9840431213378906
#                 WHERE id = 111608005
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.02031707763671875, axisz = 0.9839859008789062
#                 WHERE id = 111608006
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11593246459960938, axisy = -0.020172119140625, axisz = 0.9841346740722656
#                 WHERE id = 111608007
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.020229339599609375, axisz = 0.9843025207519531
#                 WHERE id = 111608008
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592864990234375, axisy = -0.020191192626953125, axisz = 0.9842681884765625
#                 WHERE id = 111608009
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.02020263671875, axisz = 0.9841995239257812
#                 WHERE id = 111608010
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11583709716796875, axisy = -0.02028656005859375, axisz = 0.9842338562011719
#                 WHERE id = 111608011
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11589431762695312, axisy = -0.02016448974609375, axisz = 0.9842185974121094
#                 WHERE id = 111608012
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.02008056640625, axisz = 0.9842338562011719
#                 WHERE id = 111608013
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590194702148438, axisy = -0.020160675048828125, axisz = 0.9842033386230469
#                 WHERE id = 111608014
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.020092010498046875, axisz = 0.9841690063476562
#                 WHERE id = 111608015
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11610794067382812, axisy = -0.020168304443359375, axisz = 0.9839515686035156
#                 WHERE id = 111608016
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116119384765625, axisy = -0.020214080810546875, axisz = 0.9842033386230469
#                 WHERE id = 111608017
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597061157226562, axisy = -0.02020263671875, axisz = 0.9843101501464844
#                 WHERE id = 111608018
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115936279296875, axisy = -0.020061492919921875, axisz = 0.9841957092285156
#                 WHERE id = 111608019
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11587905883789062, axisy = -0.02016448974609375, axisz = 0.9842453002929688
#                 WHERE id = 111608020
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11608123779296875, axisy = -0.020198822021484375, axisz = 0.984100341796875
#                 WHERE id = 111608021
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595535278320312, axisy = -0.020236968994140625, axisz = 0.9840049743652344
#                 WHERE id = 111608022
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020252227783203125, axisz = 0.9842414855957031
#                 WHERE id = 111608023
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160125732421875, axisy = -0.02022552490234375, axisz = 0.9842300415039062
#                 WHERE id = 111608024
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116119384765625, axisy = -0.020023345947265625, axisz = 0.98419189453125
#                 WHERE id = 111608025
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11613082885742188, axisy = -0.0201416015625, axisz = 0.9843826293945312
#                 WHERE id = 111608129
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603164672851562, axisy = -0.02025604248046875, axisz = 0.9842262268066406
#                 WHERE id = 111608130
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.020175933837890625, axisz = 0.9841194152832031
#                 WHERE id = 111608131
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11607742309570312, axisy = -0.020099639892578125, axisz = 0.9839973449707031
#                 WHERE id = 111608132
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.020267486572265625, axisz = 0.9842872619628906
#                 WHERE id = 111608133
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.0201873779296875, axisz = 0.9841651916503906
#                 WHERE id = 111608134
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600875854492188, axisy = -0.02031707763671875, axisz = 0.9842300415039062
#                 WHERE id = 111608135
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606216430664062, axisy = -0.020259857177734375, axisz = 0.9840660095214844
#                 WHERE id = 111608136
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.020111083984375, axisz = 0.9843940734863281
#                 WHERE id = 111608137
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.02019500732421875, axisz = 0.9844093322753906
#                 WHERE id = 111608138
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116119384765625, axisy = -0.02021026611328125, axisz = 0.9843215942382812
#                 WHERE id = 111608139
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.020336151123046875, axisz = 0.9840927124023438
#                 WHERE id = 111608140
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116058349609375, axisy = -0.02014923095703125, axisz = 0.9841690063476562
#                 WHERE id = 111608141
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11599349975585938, axisy = -0.020206451416015625, axisz = 0.9841423034667969
#                 WHERE id = 111608142
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1161346435546875, axisy = -0.020168304443359375, axisz = 0.9840202331542969
#                 WHERE id = 111608143
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11611175537109375, axisy = -0.0201416015625, axisz = 0.9840240478515625
#                 WHERE id = 111608144
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602783203125, axisy = -0.020111083984375, axisz = 0.9839935302734375
#                 WHERE id = 111608145
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11586761474609375, axisy = -0.02022552490234375, axisz = 0.9843330383300781
#                 WHERE id = 111608146
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11580657958984375, axisy = -0.020099639892578125, axisz = 0.9842872619628906
#                 WHERE id = 111608147
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595916748046875, axisy = -0.020175933837890625, axisz = 0.9841957092285156
#                 WHERE id = 111608148
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160125732421875, axisy = -0.020236968994140625, axisz = 0.9841880798339844
#                 WHERE id = 111608149
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11601638793945312, axisy = -0.02017974853515625, axisz = 0.9841995239257812
#                 WHERE id = 111608150
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160430908203125, axisy = -0.020313262939453125, axisz = 0.9840850830078125
#                 WHERE id = 111608151
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.020233154296875, axisz = 0.9840469360351562
#                 WHERE id = 111608152
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598968505859375, axisy = -0.020107269287109375, axisz = 0.9840660095214844
#                 WHERE id = 111608255
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590194702148438, axisy = -0.020191192626953125, axisz = 0.9842758178710938
#                 WHERE id = 111608256
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11616134643554688, axisy = -0.020221710205078125, axisz = 0.9843711853027344
#                 WHERE id = 111608257
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160736083984375, axisy = -0.02004241943359375, axisz = 0.9842605590820312
#                 WHERE id = 111608258
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11619186401367188, axisy = -0.020107269287109375, axisz = 0.9842109680175781
#                 WHERE id = 111608259
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605072021484375, axisy = -0.02020263671875, axisz = 0.98419189453125
#                 WHERE id = 111608260
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.0203094482421875, axisz = 0.9844169616699219
#                 WHERE id = 111608261
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.02020263671875, axisz = 0.9841423034667969
#                 WHERE id = 111608262
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606216430664062, axisy = -0.02020263671875, axisz = 0.9843597412109375
#                 WHERE id = 111608263
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.020153045654296875, axisz = 0.9842300415039062
#                 WHERE id = 111608264
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.020153045654296875, axisz = 0.9842033386230469
#                 WHERE id = 111608265
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115875244140625, axisy = -0.02021026611328125, axisz = 0.9842491149902344
#                 WHERE id = 111608266
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590957641601562, axisy = -0.02017974853515625, axisz = 0.9841766357421875
#                 WHERE id = 111608267
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.020252227783203125, axisz = 0.9843521118164062
#                 WHERE id = 111608268
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605453491210938, axisy = -0.020191192626953125, axisz = 0.9843025207519531
#                 WHERE id = 111608269
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595535278320312, axisy = -0.020175933837890625, axisz = 0.9842643737792969
#                 WHERE id = 111608270
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11586761474609375, axisy = -0.020183563232421875, axisz = 0.9843826293945312
#                 WHERE id = 111608271
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590957641601562, axisy = -0.02019500732421875, axisz = 0.9842948913574219
#                 WHERE id = 111608272
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590194702148438, axisy = -0.020172119140625, axisz = 0.9840087890625
#                 WHERE id = 111608273
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11610794067382812, axisy = -0.020153045654296875, axisz = 0.9840126037597656
#                 WHERE id = 111608274
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11601638793945312, axisy = -0.020198822021484375, axisz = 0.9840087890625
#                 WHERE id = 111608275
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160125732421875, axisy = -0.020214080810546875, axisz = 0.9842185974121094
#                 WHERE id = 111608276
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.020206451416015625, axisz = 0.9841995239257812
#                 WHERE id = 111608277
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11601638793945312, axisy = -0.019969940185546875, axisz = 0.9842453002929688
#                 WHERE id = 111608278
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.020328521728515625, axisz = 0.9842109680175781
#                 WHERE id = 111608382
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594390869140625, axisy = -0.02019500732421875, axisz = 0.9842338562011719
#                 WHERE id = 111608383
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591339111328125, axisy = -0.02014923095703125, axisz = 0.9843559265136719
#                 WHERE id = 111608384
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11584854125976562, axisy = -0.020175933837890625, axisz = 0.9842758178710938
#                 WHERE id = 111608385
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597824096679688, axisy = -0.020038604736328125, axisz = 0.9842681884765625
#                 WHERE id = 111608386
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11586380004882812, axisy = -0.020137786865234375, axisz = 0.9840354919433594
#                 WHERE id = 111608387
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.02020263671875, axisz = 0.9841079711914062
#                 WHERE id = 111608388
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598968505859375, axisy = -0.020122528076171875, axisz = 0.9842529296875
#                 WHERE id = 111608389
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598968505859375, axisy = -0.0201416015625, axisz = 0.9842987060546875
#                 WHERE id = 111608390
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602020263671875, axisy = -0.020092010498046875, axisz = 0.9843597412109375
#                 WHERE id = 111608391
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159515380859375, axisy = -0.020198822021484375, axisz = 0.9842681884765625
#                 WHERE id = 111608392
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602020263671875, axisy = -0.020343780517578125, axisz = 0.9843177795410156
#                 WHERE id = 111608393
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159210205078125, axisy = -0.0202484130859375, axisz = 0.9843673706054688
#                 WHERE id = 111608394
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606597900390625, axisy = -0.020252227783203125, axisz = 0.9841728210449219
#                 WHERE id = 111608395
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116058349609375, axisy = -0.020282745361328125, axisz = 0.9842033386230469
#                 WHERE id = 111608396
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.02019500732421875, axisz = 0.9840278625488281
#                 WHERE id = 111608397
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598587036132812, axisy = -0.0202178955078125, axisz = 0.9840583801269531
#                 WHERE id = 111608398
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595916748046875, axisy = -0.020172119140625, axisz = 0.9843254089355469
#                 WHERE id = 111608399
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606597900390625, axisy = -0.020099639892578125, axisz = 0.9841842651367188
#                 WHERE id = 111608400
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.020233154296875, axisz = 0.9841957092285156
#                 WHERE id = 111608401
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159210205078125, axisy = -0.02016448974609375, axisz = 0.9843215942382812
#                 WHERE id = 111608402
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11576080322265625, axisy = -0.0201263427734375, axisz = 0.9839973449707031
#                 WHERE id = 111608403
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11585235595703125, axisy = -0.020313262939453125, axisz = 0.984039306640625
#                 WHERE id = 111608404
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11609649658203125, axisy = -0.02011871337890625, axisz = 0.9842376708984375
#                 WHERE id = 111608405
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115936279296875, axisy = -0.020198822021484375, axisz = 0.9842376708984375
#                 WHERE id = 111608434
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595916748046875, axisy = -0.020168304443359375, axisz = 0.9842376708984375
#                 WHERE id = 111608435
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11587905883789062, axisy = -0.02013397216796875, axisz = 0.9843406677246094
#                 WHERE id = 111608436
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159210205078125, axisy = -0.020130157470703125, axisz = 0.9843406677246094
#                 WHERE id = 111608437
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020221710205078125, axisz = 0.9841461181640625
#                 WHERE id = 111608438
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605072021484375, axisy = -0.02022552490234375, axisz = 0.9841423034667969
#                 WHERE id = 111608439
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11608505249023438, axisy = -0.02021026611328125, axisz = 0.9840431213378906
#                 WHERE id = 111608440
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11608505249023438, axisy = -0.02033233642578125, axisz = 0.9841423034667969
#                 WHERE id = 111608441
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11582565307617188, axisy = -0.020221710205078125, axisz = 0.9842300415039062
#                 WHERE id = 111608442
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598968505859375, axisy = -0.02033233642578125, axisz = 0.9842758178710938
#                 WHERE id = 111608443
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597061157226562, axisy = -0.020160675048828125, axisz = 0.9843063354492188
#                 WHERE id = 111608444
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.0202484130859375, axisz = 0.9841499328613281
#                 WHERE id = 111608445
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590576171875, axisy = -0.020168304443359375, axisz = 0.9844017028808594
#                 WHERE id = 111608446
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597824096679688, axisy = -0.020092010498046875, axisz = 0.984375
#                 WHERE id = 111608447
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115966796875, axisy = -0.02007293701171875, axisz = 0.9845199584960938
#                 WHERE id = 111608448
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159515380859375, axisy = -0.020084381103515625, axisz = 0.9843978881835938
#                 WHERE id = 111608449
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11593246459960938, axisy = -0.020294189453125, axisz = 0.9841842651367188
#                 WHERE id = 111608450
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11613082885742188, axisy = -0.02022552490234375, axisz = 0.9841766357421875
#                 WHERE id = 111608451
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020046234130859375, axisz = 0.9841232299804688
#                 WHERE id = 111608452
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602020263671875, axisy = -0.0201416015625, axisz = 0.983734130859375
#                 WHERE id = 111608453
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.020267486572265625, axisz = 0.98406982421875
#                 WHERE id = 111608454
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605072021484375, axisy = -0.020175933837890625, axisz = 0.9841690063476562
#                 WHERE id = 111608455
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.02028656005859375, axisz = 0.9841384887695312
#                 WHERE id = 111608456
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11608123779296875, axisy = -0.020160675048828125, axisz = 0.9844627380371094
#                 WHERE id = 111608457
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11615753173828125, axisy = -0.02022552490234375, axisz = 0.9841117858886719
#                 WHERE id = 111608486
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603164672851562, axisy = -0.020259857177734375, axisz = 0.9841194152832031
#                 WHERE id = 111608487
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.020233154296875, axisz = 0.9841156005859375
#                 WHERE id = 111608488
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606216430664062, axisy = -0.020206451416015625, axisz = 0.9840545654296875
#                 WHERE id = 111608489
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597824096679688, axisy = -0.020111083984375, axisz = 0.984344482421875
#                 WHERE id = 111608490
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.02005767822265625, axisz = 0.9844207763671875
#                 WHERE id = 111608491
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605072021484375, axisy = -0.02010345458984375, axisz = 0.9843978881835938
#                 WHERE id = 111608492
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606216430664062, axisy = -0.020229339599609375, axisz = 0.9841766357421875
#                 WHERE id = 111608493
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11607742309570312, axisy = -0.0202178955078125, axisz = 0.9840965270996094
#                 WHERE id = 111608494
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11608123779296875, axisy = -0.020099639892578125, axisz = 0.9843559265136719
#                 WHERE id = 111608495
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.0200958251953125, axisz = 0.98419189453125
#                 WHERE id = 111608496
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603927612304688, axisy = -0.0201568603515625, axisz = 0.9840354919433594
#                 WHERE id = 111608497
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11583709716796875, axisy = -0.020198822021484375, axisz = 0.984039306640625
#                 WHERE id = 111608498
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.02030181884765625, axisz = 0.9841270446777344
#                 WHERE id = 111608499
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603164672851562, axisy = -0.020137786865234375, axisz = 0.9843254089355469
#                 WHERE id = 111608500
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594772338867188, axisy = -0.020111083984375, axisz = 0.9843025207519531
#                 WHERE id = 111608501
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11604690551757812, axisy = -0.0201568603515625, axisz = 0.9843368530273438
#                 WHERE id = 111608502
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.02025604248046875, axisz = 0.9843330383300781
#                 WHERE id = 111608503
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11579132080078125, axisy = -0.020076751708984375, axisz = 0.9840888977050781
#                 WHERE id = 111608504
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11599349975585938, axisy = -0.020153045654296875, axisz = 0.9841423034667969
#                 WHERE id = 111608505
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11617279052734375, axisy = -0.02016448974609375, axisz = 0.9843673706054688
#                 WHERE id = 111608506
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598587036132812, axisy = -0.0202789306640625, axisz = 0.984344482421875
#                 WHERE id = 111608507
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595916748046875, axisy = -0.020111083984375, axisz = 0.9839591979980469
#                 WHERE id = 111608508
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591720581054688, axisy = -0.02016448974609375, axisz = 0.9841461181640625
#                 WHERE id = 111608509
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594772338867188, axisy = -0.020214080810546875, axisz = 0.9842910766601562
#                 WHERE id = 111608563
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602020263671875, axisy = -0.02013397216796875, axisz = 0.9841842651367188
#                 WHERE id = 111608564
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11580276489257812, axisy = -0.020053863525390625, axisz = 0.9841728210449219
#                 WHERE id = 111608565
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591339111328125, axisy = -0.020107269287109375, axisz = 0.9842300415039062
#                 WHERE id = 111608566
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11582183837890625, axisy = -0.0203857421875, axisz = 0.9841346740722656
#                 WHERE id = 111608567
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1158905029296875, axisy = -0.020084381103515625, axisz = 0.9842453002929688
#                 WHERE id = 111608568
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598587036132812, axisy = -0.02007293701171875, axisz = 0.9843063354492188
#                 WHERE id = 111608569
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115966796875, axisy = -0.020153045654296875, axisz = 0.9842414855957031
#                 WHERE id = 111608570
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597061157226562, axisy = -0.020099639892578125, axisz = 0.9842681884765625
#                 WHERE id = 111608571
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020099639892578125, axisz = 0.9841651916503906
#                 WHERE id = 111608572
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11604690551757812, axisy = -0.02011871337890625, axisz = 0.9841537475585938
#                 WHERE id = 111608573
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603927612304688, axisy = -0.02014923095703125, axisz = 0.9841346740722656
#                 WHERE id = 111608574
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.0202484130859375, axisz = 0.9843559265136719
#                 WHERE id = 111608575
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597061157226562, axisy = -0.02031707763671875, axisz = 0.9843521118164062
#                 WHERE id = 111608576
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11587142944335938, axisy = -0.02010345458984375, axisz = 0.9844551086425781
#                 WHERE id = 111608577
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11588287353515625, axisy = -0.02004241943359375, axisz = 0.9843940734863281
#                 WHERE id = 111608578
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594772338867188, axisy = -0.020053863525390625, axisz = 0.984222412109375
#                 WHERE id = 111608579
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11611557006835938, axisy = -0.02021026611328125, axisz = 0.9841575622558594
#                 WHERE id = 111608580
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020263671875, axisz = 0.9842376708984375
#                 WHERE id = 111608581
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603164672851562, axisy = -0.02025604248046875, axisz = 0.9842453002929688
#                 WHERE id = 111608582
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.0202178955078125, axisz = 0.9841384887695312
#                 WHERE id = 111608583
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020263671875, axisz = 0.9840278625488281
#                 WHERE id = 111608584
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11601638793945312, axisy = -0.0201263427734375, axisz = 0.9841690063476562
#                 WHERE id = 111608585
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159210205078125, axisy = -0.02010345458984375, axisz = 0.984283447265625
#                 WHERE id = 111608586
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600875854492188, axisy = -0.020183563232421875, axisz = 0.9842033386230469
#                 WHERE id = 111608640
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.02025604248046875, axisz = 0.9841575622558594
#                 WHERE id = 111608641
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600875854492188, axisy = -0.020267486572265625, axisz = 0.9840736389160156
#                 WHERE id = 111608642
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11591339111328125, axisy = -0.020076751708984375, axisz = 0.9841804504394531
#                 WHERE id = 111608643
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116119384765625, axisy = -0.0203094482421875, axisz = 0.9843597412109375
#                 WHERE id = 111608644
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597824096679688, axisy = -0.020172119140625, axisz = 0.9842376708984375
#                 WHERE id = 111608645
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603164672851562, axisy = -0.020252227783203125, axisz = 0.9844512939453125
#                 WHERE id = 111608646
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598587036132812, axisy = -0.020294189453125, axisz = 0.984222412109375
#                 WHERE id = 111608647
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11588668823242188, axisy = -0.020313262939453125, axisz = 0.9839820861816406
#                 WHERE id = 111608648
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11588287353515625, axisy = -0.02022552490234375, axisz = 0.9842147827148438
#                 WHERE id = 111608649
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.020137786865234375, axisz = 0.9840583801269531
#                 WHERE id = 111608650
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.0200347900390625, axisz = 0.9842567443847656
#                 WHERE id = 111608651
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595535278320312, axisy = -0.020114898681640625, axisz = 0.9842376708984375
#                 WHERE id = 111608652
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115966796875, axisy = -0.020172119140625, axisz = 0.9843406677246094
#                 WHERE id = 111608653
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160888671875, axisy = -0.02022552490234375, axisz = 0.9844284057617188
#                 WHERE id = 111608654
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020175933837890625, axisz = 0.9842567443847656
#                 WHERE id = 111608655
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.020084381103515625, axisz = 0.9841651916503906
#                 WHERE id = 111608656
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.020076751708984375, axisz = 0.98394775390625
#                 WHERE id = 111608657
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1158905029296875, axisy = -0.020313262939453125, axisz = 0.9841880798339844
#                 WHERE id = 111608658
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11587142944335938, axisy = -0.0201263427734375, axisz = 0.9843597412109375
#                 WHERE id = 111608659
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159515380859375, axisy = -0.020030975341796875, axisz = 0.9841651916503906
#                 WHERE id = 111608660
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11587142944335938, axisy = -0.020305633544921875, axisz = 0.9840087890625
#                 WHERE id = 111608661
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11589813232421875, axisy = -0.02014923095703125, axisz = 0.9840431213378906
#                 WHERE id = 111608662
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11612319946289062, axisy = -0.020275115966796875, axisz = 0.9843063354492188
#                 WHERE id = 111608663
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.020168304443359375, axisz = 0.9840126037597656
#                 WHERE id = 111608717
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11607742309570312, axisy = -0.02020263671875, axisz = 0.9841270446777344
#                 WHERE id = 111608718
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160888671875, axisy = -0.020160675048828125, axisz = 0.9841079711914062
#                 WHERE id = 111608719
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115966796875, axisy = -0.020069122314453125, axisz = 0.9841041564941406
#                 WHERE id = 111608720
# ...
#                 WHERE id = 111611616
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159515380859375, axisy = -0.020244598388671875, axisz = 0.9841537475585938
#                 WHERE id = 111611645
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602783203125, axisy = -0.020214080810546875, axisz = 0.9842071533203125
#                 WHERE id = 111611646
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160430908203125, axisy = -0.020191192626953125, axisz = 0.9840431213378906
#                 WHERE id = 111611647
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.020111083984375, axisz = 0.9841651916503906
#                 WHERE id = 111611648
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115875244140625, axisy = -0.020191192626953125, axisz = 0.9840888977050781
#                 WHERE id = 111611649
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11597442626953125, axisy = -0.020069122314453125, axisz = 0.9841690063476562
#                 WHERE id = 111611650
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603546142578125, axisy = -0.020114898681640625, axisz = 0.9841842651367188
#                 WHERE id = 111611651
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11612319946289062, axisy = -0.020122528076171875, axisz = 0.9841384887695312
#                 WHERE id = 111611652
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605453491210938, axisy = -0.020221710205078125, axisz = 0.9842109680175781
#                 WHERE id = 111611653
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.0200958251953125, axisz = 0.98419189453125
#                 WHERE id = 111611654
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020168304443359375, axisz = 0.9840087890625
#                 WHERE id = 111611655
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.0201416015625, axisz = 0.9841957092285156
#                 WHERE id = 111611656
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594390869140625, axisy = -0.0203094482421875, axisz = 0.9841690063476562
#                 WHERE id = 111611657
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11596298217773438, axisy = -0.02017974853515625, axisz = 0.9842262268066406
#                 WHERE id = 111611658
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.0203094482421875, axisz = 0.9841842651367188
#                 WHERE id = 111611659
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020267486572265625, axisz = 0.9840812683105469
#                 WHERE id = 111611660
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11604690551757812, axisy = -0.0202484130859375, axisz = 0.98419189453125
#                 WHERE id = 111611661
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.0202789306640625, axisz = 0.9841575622558594
#                 WHERE id = 111611662
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11605453491210938, axisy = -0.0201568603515625, axisz = 0.9841804504394531
#                 WHERE id = 111611663
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11607742309570312, axisy = -0.0202178955078125, axisz = 0.984344482421875
#                 WHERE id = 111611664
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606597900390625, axisy = -0.020236968994140625, axisz = 0.9841690063476562
#                 WHERE id = 111611665
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592483520507812, axisy = -0.02034759521484375, axisz = 0.9840965270996094
#                 WHERE id = 111611666
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11599349975585938, axisy = -0.02020263671875, axisz = 0.9842109680175781
#                 WHERE id = 111611667
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603546142578125, axisy = -0.020092010498046875, axisz = 0.9844551086425781
#                 WHERE id = 111611668
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11617660522460938, axisy = -0.020259857177734375, axisz = 0.9840927124023438
#                 WHERE id = 111611772
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.02024078369140625, axisz = 0.9842338562011719
#                 WHERE id = 111611773
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.020160675048828125, axisz = 0.9842071533203125
#                 WHERE id = 111611774
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11588287353515625, axisy = -0.0201873779296875, axisz = 0.9843292236328125
#                 WHERE id = 111611775
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115936279296875, axisy = -0.02007293701171875, axisz = 0.984100341796875
#                 WHERE id = 111611776
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11601638793945312, axisy = -0.020111083984375, axisz = 0.9841346740722656
#                 WHERE id = 111611777
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160736083984375, axisy = -0.020145416259765625, axisz = 0.9842376708984375
#                 WHERE id = 111611778
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602783203125, axisy = -0.02010345458984375, axisz = 0.9842109680175781
#                 WHERE id = 111611779
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11612701416015625, axisy = -0.02022552490234375, axisz = 0.9841995239257812
#                 WHERE id = 111611780
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600112915039062, axisy = -0.020320892333984375, axisz = 0.9840240478515625
#                 WHERE id = 111611781
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160125732421875, axisy = -0.020290374755859375, axisz = 0.9840621948242188
#                 WHERE id = 111611782
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160430908203125, axisy = -0.020343780517578125, axisz = 0.9842147827148438
#                 WHERE id = 111611783
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.020290374755859375, axisz = 0.9843025207519531
#                 WHERE id = 111611784
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1161041259765625, axisy = -0.020313262939453125, axisz = 0.9843826293945312
#                 WHERE id = 111611785
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11613082885742188, axisy = -0.02022552490234375, axisz = 0.9841423034667969
#                 WHERE id = 111611786
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020259857177734375, axisz = 0.9841270446777344
#                 WHERE id = 111611787
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598587036132812, axisy = -0.020191192626953125, axisz = 0.9843978881835938
#                 WHERE id = 111611788
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.020175933837890625, axisz = 0.9842987060546875
#                 WHERE id = 111611789
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.116119384765625, axisy = -0.02019500732421875, axisz = 0.984161376953125
#                 WHERE id = 111611790
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606597900390625, axisy = -0.020351409912109375, axisz = 0.984405517578125
#                 WHERE id = 111611791
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606597900390625, axisy = -0.02020263671875, axisz = 0.9842491149902344
#                 WHERE id = 111611792
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.020294189453125, axisz = 0.9839706420898438
#                 WHERE id = 111611793
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598968505859375, axisy = -0.02033233642578125, axisz = 0.984130859375
#                 WHERE id = 111611794
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11595535278320312, axisy = -0.020172119140625, axisz = 0.9842529296875
#                 WHERE id = 111611795
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592864990234375, axisy = -0.020023345947265625, axisz = 0.9842796325683594
#                 WHERE id = 111611948
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115936279296875, axisy = -0.020069122314453125, axisz = 0.9841995239257812
#                 WHERE id = 111611949
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11611175537109375, axisy = -0.020175933837890625, axisz = 0.9841575622558594
#                 WHERE id = 111611950
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159515380859375, axisy = -0.02014923095703125, axisz = 0.9842567443847656
#                 WHERE id = 111611951
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11592864990234375, axisy = -0.020206451416015625, axisz = 0.9840965270996094
#                 WHERE id = 111611952
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11602401733398438, axisy = -0.020282745361328125, axisz = 0.9841995239257812
#                 WHERE id = 111611953
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1159820556640625, axisy = -0.0201568603515625, axisz = 0.9842109680175781
#                 WHERE id = 111611954
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.020122528076171875, axisz = 0.984161376953125
#                 WHERE id = 111611955
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11613845825195312, axisy = -0.0202484130859375, axisz = 0.9842071533203125
#                 WHERE id = 111611956
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603546142578125, axisy = -0.0201873779296875, axisz = 0.9839935302734375
#                 WHERE id = 111611957
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594772338867188, axisy = -0.02008056640625, axisz = 0.9842109680175781
#                 WHERE id = 111611958
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11601638793945312, axisy = -0.020168304443359375, axisz = 0.9844017028808594
#                 WHERE id = 111611959
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11594009399414062, axisy = -0.020137786865234375, axisz = 0.9843940734863281
#                 WHERE id = 111611960
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020294189453125, axisz = 0.9840774536132812
#                 WHERE id = 111611961
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11609268188476562, axisy = -0.020172119140625, axisz = 0.9842529296875
#                 WHERE id = 111611962
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11612319946289062, axisy = -0.020267486572265625, axisz = 0.9841957092285156
#                 WHERE id = 111611963
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.1160430908203125, axisy = -0.02008056640625, axisz = 0.9841957092285156
#                 WHERE id = 111611964
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.115997314453125, axisy = -0.020153045654296875, axisz = 0.9843711853027344
#                 WHERE id = 111611965
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11590957641601562, axisy = -0.02007293701171875, axisz = 0.9843101501464844
#                 WHERE id = 111611966
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11600494384765625, axisy = -0.020236968994140625, axisz = 0.9842987060546875
#                 WHERE id = 111611967
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11598968505859375, axisy = -0.02011871337890625, axisz = 0.9841651916503906
#                 WHERE id = 111611968
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11593246459960938, axisy = -0.020137786865234375, axisz = 0.9842414855957031
#                 WHERE id = 111611969
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11606979370117188, axisy = -0.020244598388671875, axisz = 0.9840316772460938
#                 WHERE id = 111611970
#
#
#                 UPDATE data_accelerometer
#                 SET axisx = 0.11603927612304688, axisy = -0.0201873779296875, axisz = 0.9842720031738281
#                 WHERE id = 111611971
# /tmp/ipykernel_177082/3464387567.py:81: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('data_block').apply(correct_axes).reset_index(drop=True)
#                                    x         y         z  data_block
# datetime
# 2025-03-01 00:00:08.142464  0.984474  0.115868 -0.020126     3299349
# 2025-03-01 00:00:08.150464  0.984226  0.115875 -0.020184     3299349
# 2025-03-01 00:00:08.158464  0.984188  0.115829 -0.020252     3299349
# 2025-03-01 00:00:08.166464  0.984344  0.115883 -0.020226     3299349
# 2025-03-01 00:00:08.174464  0.984364  0.115711 -0.020287     3299349
# ...                              ...       ...       ...         ...
# 2025-03-01 23:59:58.166136  0.116005 -0.020237  0.984299     4058653
# 2025-03-01 23:59:58.174136  0.115990 -0.020119  0.984165     4058653
# 2025-03-01 23:59:58.182136  0.115932 -0.020138  0.984241     4058653
# 2025-03-01 23:59:58.190136  0.116070 -0.020245  0.984032     4058653
# 2025-03-01 23:59:58.198136  0.116039 -0.020187  0.984272     4058653
#
# [1148562 rows x 4 columns]

# %%
# Arreglar datablocks que todas sus muestras tengan los ejes intercambiados

datablock_stats = get_stats_datablocks(ACELEROMETRO, FECHA_HORA_INICIO, FECHA_HORA_FIN) # Obtener nuevamente los datablocks para recalcular las nuevas medias
datablock_fixed_stats = fix_datablocks(datablock_stats, THRESHOLD_FIX_DATABLOCKS)
# Out:
#                 UPDATE data_accelerometer AS d
#                 JOIN (
#                     SELECT id, axisx AS old_axisx, axisy AS old_axisy, axisz AS old_axisz
#                     FROM data_accelerometer
#                     WHERE data_block = 3525399
#                 ) AS temp
#                 ON d.id = temp.id
#                 SET d.axisx = temp.old_axisz,
#                     d.axisy = temp.old_axisx,
#                     d.axisz = temp.old_axisy
#                 WHERE d.data_block = 3525399;
#
#
#
#                 UPDATE data_accelerometer AS d
#                 JOIN (
#                     SELECT id, axisx AS old_axisx, axisy AS old_axisy, axisz AS old_axisz
#                     FROM data_accelerometer
#                     WHERE data_block = 3545977
#                 ) AS temp
#                 ON d.id = temp.id
#                 SET d.axisx = temp.old_axisz,
#                     d.axisy = temp.old_axisx,
#                     d.axisz = temp.old_axisy
#                 WHERE d.data_block = 3545977;

# %% [markdown]
# # Datos finales

# %%
# Volver a obtener los datos de la base de datos. Los datos ya deberian mostrarse arreglados
# Podrá haber algunas muestras erroneas de determinados datablocks

data = get_acelerometer_data(ACELEROMETRO, FECHA_HORA_INICIO, FECHA_HORA_FIN)
df = plot_acelerometer_data(data)

# %%
plot_acelerometer_data(data, axes=['z'], min_date='2025-03-01 13:52:10', max_date='2025-03-01 13:52:15')
# Out:
#                                    x         y         z  data_block
# datetime
# 2025-03-01 13:52:10.001868  0.118637 -0.019688  0.992691     3782089
# 2025-03-01 13:52:10.009868  0.118164 -0.016376  0.996128     3782089
# 2025-03-01 13:52:10.017868  0.121002 -0.022369  0.988285     3782089
# 2025-03-01 13:52:10.025868  0.115242 -0.019493  0.966675     3782089
# 2025-03-01 13:52:10.033868  0.114441 -0.018490  0.973530     3782089
# ...                              ...       ...       ...         ...
# 2025-03-01 13:52:14.961868  0.116611 -0.020573  0.984737     3782139
# 2025-03-01 13:52:14.969868  0.116650 -0.020405  0.985397     3782139
# 2025-03-01 13:52:14.977868  0.116444 -0.020741  0.985859     3782139
# 2025-03-01 13:52:14.985868  0.116299 -0.020847  0.984833     3782139
# 2025-03-01 13:52:14.993868  0.116337 -0.020370  0.984516     3782139
#
# [624 rows x 4 columns]
